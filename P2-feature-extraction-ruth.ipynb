# %%
import requests
import os
import base64

GITHUB_TOKEN = os.environ["GITHUB_API"]

# %%
#Check for setup files

SETUP_FILES = {
    "Python": ["requirements.txt", "setup.py"],
    "C/C++": ["CMakeLists.txt", "Makefile"],
    "Java": ["pom.xml", "build.gradle"],
    "R": ["DESCRIPTION", "NAMESPACE"],
    "Julia": ["Project.toml", "Manifest.toml"]
}

DOCKER_FILES = {
    "Docker": ["Dockerfile", "docker-compose.yml"]
}

# GitHub API headers
HEADERS = {
    "Authorization": f"token {GITHUB_TOKEN}",
    "Accept": "application/vnd.github.v3+json"
}

def get_repo_files(url):
    """Fetch the file structure of the repository."""
    parts = url.split("/")
    owner = parts[3]
    repo = parts[4]
    url = f"https://api.github.com/repos/{owner}/{repo}/contents"
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error: {response.status_code}, {response.json().get('message', 'No message')}")
        return []

# to set to docker change setup_files to DOCKER_FILES
def find_setup_files(files, setup_files = SETUP_FILES):
    """Check for the presence of setup files."""
    found_files = {}
    for language, filenames in setup_files.items():
        found_files[language] = []
        for file in files:
            for filename in filenames:
                # print(file["name"], filename)
                if file["name"].lower() == filename.lower():
                    return True
    return False

# %%
# check for setup in readme

import re

def check_keywords(readme_text, keywords):
    """Check for presence of keywords in README."""

    keyword_matches = {keyword: re.search(rf"\b{keyword}\b", readme_text, re.IGNORECASE) 
                       for keyword in keywords}
    return {kw: match.group(0) for kw, match in keyword_matches.items() if match}

def enviroment_setup(readme):
    """
    Check if readme includes how to setup the environment / dependencies
    """
    keywords = [
        # General setup terms
        "requirements", "dependencies", "environment", "install", "setup", 
        "virtualenv", "pip", "docker", "build", "configuration",
        "environment.yaml", "requirements.txt", 

        # MATLAB-specific terms
        "MATLAB", "matlabpath", "toolbox", "mex", "matlab script", "matlab install",

        # C/C++-specific terms
        "makefile", "gcc", "g\+\+", "cmake", "make", "compile", "C compiler", "C\+\+ compiler",

        # Java-specific terms
        "JDK", "Maven", "Gradle", "java -jar", "javac", "java version", "Java SDK",

        # R-specific terms
        "R package", "CRAN", "install.packages", "Rscript", "R environment", "R version"
    ]

    if not readme:
        return {}
    
    matches = check_keywords(readme, keywords)
    return True if matches else False

# %%
import re

def get_readme_from_github(url):
    parts = url.split("/")
    owner = parts[3]
    repo = parts[4]

    # GitHub API URL for the repository README
    url = f"https://api.github.com/repos/{owner}/{repo}/readme"
    headers = {
        "Accept": "application/vnd.github.v3+json",
        "Authorization": f"token {GITHUB_TOKEN}",
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        readme_data = response.json()
        readme_content_base64 = readme_data.get("content", "")
        # Decode the base64 content
        readme_content = base64.b64decode(readme_content_base64).decode('utf-8')
        return readme_content
    else:
        print(f"Error: Unable to fetch README (status code: {response.status_code}) " + url)
        return ""

def check_keywords(readme_text, keywords):
    """Check for presence of keywords in README."""

    keyword_matches = {keyword: re.search(rf"\b{keyword}\b", readme_text, re.IGNORECASE) 
                       for keyword in keywords}
    return {kw: match.group(0) for kw, match in keyword_matches.items() if match}


def shell_commands(readme):
    """
    Check if readme includes commands that can be run to reproduce data
    """

    keywords = [
        "command line", "terminal", "CLI", "script", "bash", "shell"
    ]

    if not readme:
        return {}
    
    matches = check_keywords(readme, keywords)
    return True if matches else False

def notebook_commands(readme):
    """
    Check if readme includes a notebook that can be run to reproduce data
    """
    '''keywords = [
        "run", "execute", "executable", "command", "reproduce", "steps", "usage", 
        "experiment", "reproduction", "how to run", "command line", 
        "terminal", "CLI", "script", "bash", "shell", "notebook", "ipynb", "notebooks"
    ]'''

    keywords = [
        "notebook", "ipynb", "notebooks"
    ]

    if not readme:
        return {}
    
    matches = check_keywords(readme, keywords)
    return True if matches else False

def contains_runnable_code(readme_content):
    """
    Check if the README contains mentions of runnable code files.
    
    Parameters:
        readme_content (str): The content of the README file as a string.
    
    Returns:
        bool: True if any runnable code file is mentioned, False otherwise.
    """
    # Define regex pattern for runnable code files
    code_file_pattern = r'\b[\w-]+\.(py|c|cpp|java|r|m|jl|ipynb)\b'
    
    # Search for the pattern in the README content
    matches = re.findall(code_file_pattern, readme_content, re.IGNORECASE)
    
    if matches:
        # print(f"Found runnable code files: {set(matches)}")
        return True
    else:
        # print("No runnable code files found.")
        return False

# %%
import json

def get_title_and_links(json_file_path):
    with open(json_file_path, 'r') as file:
        data = json.load(file)
        
        results = []
        for entry in data:
            if 'title' in entry and 'github_urls' in entry:
                results.append({
                    "title": entry['title'],
                    "github_urls": entry['github_urls']
                })
        
        return results

# %%
github_info = get_title_and_links("/Users/ruth/Downloads/rr-measure-basic/P1-v1/github_data.json")

# %%
import pandas as pd

columns = [
        "Title",
        "Github_urls",
        "setup_files",
        "docker_files",
        "setup_info_in_readme",
        "shell_instructions_in_readme",
        "notebook_instructions_in_readme",
        "code_instructions_in_readme"
    ]

df = pd.DataFrame(columns=columns)

for col in columns[1:]:
        df[col] = df[col].astype(object)

# %%
for item in github_info:
    row = [item["title"]]
    setup_files_list = []
    docker_files_list = []
    setup_info_list = []
    shell_ins_list = []
    notebook_ins_list = []
    code_ins_list = []
    
    for link in item["github_urls"]:
        readme = get_readme_from_github(link)
        files = get_repo_files(link)
        if readme or files:
            setup_files_list.append(find_setup_files(files))
            docker_files_list.append(find_setup_files(files, setup_files = DOCKER_FILES))
            setup_info_list.append(enviroment_setup(readme))
            shell_ins_list.append(shell_commands(readme))
            notebook_ins_list.append(notebook_commands(readme))
            code_ins_list.append(contains_runnable_code(readme))
        else:
            # print("repo not found")
            setup_files_list.append("Repo not found")
            docker_files_list.append("Repo not found")
            setup_info_list.append("Repo not found")
            shell_ins_list.append("Repo not found")
            notebook_ins_list.append("Repo not found")
            code_ins_list.append("Repo not found")


    row.append(item["github_urls"])
    row.append(setup_files_list)
    row.append(docker_files_list)
    row.append(setup_info_list)
    row.append(shell_ins_list)
    row.append(notebook_ins_list)
    row.append(code_ins_list)

    # print(row)

    df.loc[len(df)] = row
# Out:
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/mahi045/JMetal4/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Moccino17/Transport_Mode_Sklearn/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/JusteRaimbault/EnergyPriceAt/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/jimioke/mitei-prototype-cities/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/giovanni-cal/future-transit/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Sangen-Hu/Bus-stop-Simulation/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/AliMaurenne/Microeconomic-model-of-ridesourcing-/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/yudiaspen/sensor-bias-estimation/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/YXZhangSWJTU/CyclicTrainTimetabling_ETSN/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/xzhou99/Agent-Plus/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/YaoYuBJTU/ADMM_Python/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/pflee2002/Multi-Intersection-Control-GAMS-CODE35T/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/zhangqin635/IntegratedOptimizationMTData/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/sunnyqywang/demand_image/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/YaomingZhou/MultilayerEfficiency-LWNE/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/BUILTNYU/PDPSET/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/ivangipa/FirstMile/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/delarami/HHC/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/418399/COVID-19-related-data/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/omerfarukktu/MSCresilience/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/bstabler/TransportaionNetworks/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/418399/DRO_CERN_Design/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Yida-Ding/ADM-Research/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/amatc2/Graph-Multi-Attention-Network/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/ltbstudy/MAB-HH-test-data/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/meituan/Meituan-INFORMS-TSL-Research-Challenge/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Shenglin807/SARP_RL_Dataset/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/FwDeng/ODPFM/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/wenbo-purdue-git/isttt-23-taxi-system-modeling-/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Jishnuns/IntegratedFixedFlexibleRouteChoiceAssignment/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/TonyLiu2015/AVRLite/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Panchamy/3D-Partitioning/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/ronan-keane/havsim/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/zhengyunhan/Equality-of-Opportunity-Travel-Behavior/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Amelia55/Adaptive-Control-System-for-UAM/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/gsfeir/GBM-LCCM/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/gsfeir/GP-LCCM/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/leeke2/tt-sync-scenarios/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/ChengTraffic/Polynomial-Arrival-Queue-PAQ/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/HossseinMoradi/Project1/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/HossseinMoradi/Project2/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/ramondalmau/Machine-learning-for-ATFM/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/lucktroy/DeepST/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/ivechan/PVCGNZ/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/jiawlu/Traffic_State_Estimation-Computational_Graph/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/asu-trans-ai-lab/CAMLite/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/ljq19920202/MotionPrediction_for_bicycles/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/bstabler/Transportationetworks/readme
# Error: 404, Not Found
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Milad-Haghani/Physical-movement-of-individuals/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Milad-Haghani/Decision-making-of-individuals/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/NicoleZlq/metro-expansion/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/Mahla1368-ops/Cplex/readme
# Error: Unable to fetch README (status code: 404) https://api.github.com/repos/maitien86/RecursiveLogit/readme

# %%
df.to_csv("readme_setup_checks.csv")

# %%
bc_files = get_repo_files("https://github.com/battlecode/battlecode24")
find_setup_files(bc_files)
# Out:
# True

# %%
print(bc_files)
# Out:
# [{'name': '.github', 'path': '.github', 'sha': '2760895f19c73d35c8d9259470363c3aa56ecfa3', 'size': 0, 'url': 'https://api.github.com/repos/battlecode/battlecode24/contents/.github?ref=master', 'html_url': 'https://github.com/battlecode/battlecode24/tree/master/.github', 'git_url': 'https://api.github.com/repos/battlecode/battlecode24/git/trees/2760895f19c73d35c8d9259470363c3aa56ecfa3', 'download_url': None, 'type': 'dir', '_links': {'self': 'https://api.github.com/repos/battlecode/battlecode24/contents/.github?ref=master', 'git': 'https://api.github.com/repos/battlecode/battlecode24/git/trees/2760895f19c73d35c8d9259470363c3aa56ecfa3', 'html': 'https://github.com/battlecode/battlecode24/tree/master/.github'}}, {'name': '.gitignore', 'path': '.gitignore', 'sha': '3ceda31f4908f929ae44281fa63c1c9623688385', 'size': 803, 'url': 'https://api.github.com/repos/battlecode/battlecode24/contents/.gitignore?ref=master', 'html_url': 'https://github.com/battlecode/battlecode24/blob/master/.gitignore', 'git_url': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/3ceda31f4908f929ae44281fa63c1c9623688385', 'download_url': 'https://raw.githubusercontent.com/battlecode/battlecode24/master/.gitignore', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/battlecode/battlecode24/contents/.gitignore?ref=master', 'git': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/3ceda31f4908f929ae44281fa63c1c9623688385', 'html': 'https://github.com/battlecode/battlecode24/blob/master/.gitignore'}}, {'name': 'README.md', 'path': 'README.md', 'sha': '52ed0a4c7c09095699bec3ee32c03734c69ac997', 'size': 2500, 'url': 'https://api.github.com/repos/battlecode/battlecode24/contents/README.md?ref=master', 'html_url': 'https://github.com/battlecode/battlecode24/blob/master/README.md', 'git_url': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/52ed0a4c7c09095699bec3ee32c03734c69ac997', 'download_url': 'https://raw.githubusercontent.com/battlecode/battlecode24/master/README.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/battlecode/battlecode24/contents/README.md?ref=master', 'git': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/52ed0a4c7c09095699bec3ee32c03734c69ac997', 'html': 'https://github.com/battlecode/battlecode24/blob/master/README.md'}}, {'name': 'RELEASE_JAVA.md', 'path': 'RELEASE_JAVA.md', 'sha': '59a55dd30c7954f1a4d7bc078e9e082362158914', 'size': 521, 'url': 'https://api.github.com/repos/battlecode/battlecode24/contents/RELEASE_JAVA.md?ref=master', 'html_url': 'https://github.com/battlecode/battlecode24/blob/master/RELEASE_JAVA.md', 'git_url': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/59a55dd30c7954f1a4d7bc078e9e082362158914', 'download_url': 'https://raw.githubusercontent.com/battlecode/battlecode24/master/RELEASE_JAVA.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/battlecode/battlecode24/contents/RELEASE_JAVA.md?ref=master', 'git': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/59a55dd30c7954f1a4d7bc078e9e082362158914', 'html': 'https://github.com/battlecode/battlecode24/blob/master/RELEASE_JAVA.md'}}, {'name': 'RELEASE_PYTHON.md', 'path': 'RELEASE_PYTHON.md', 'sha': '98b3de44b7b1fce03eb189c9b8bea8deb4b8345e', 'size': 347, 'url': 'https://api.github.com/repos/battlecode/battlecode24/contents/RELEASE_PYTHON.md?ref=master', 'html_url': 'https://github.com/battlecode/battlecode24/blob/master/RELEASE_PYTHON.md', 'git_url': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/98b3de44b7b1fce03eb189c9b8bea8deb4b8345e', 'download_url': 'https://raw.githubusercontent.com/battlecode/battlecode24/master/RELEASE_PYTHON.md', 'type': 'file', '_links': {'self': 'https://api.github.com/repos/battlecode/battlecode24/contents/RELEASE_PYTHON.md?ref=master', 'git': 'https://api.github.com/repos/battlecode/battlecode24/git/blobs/98b3de44b7b1fce03eb189c9b8bea8deb4b8345e', 'html': 'https://github.com/battlecode/ba ...
